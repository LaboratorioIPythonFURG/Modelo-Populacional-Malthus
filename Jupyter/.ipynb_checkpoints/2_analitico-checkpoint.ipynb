# %% [markdown]
# <h1 style='color:#0000ec'>2 &nbsp; Modelos de Malthus, Verhulst e Montroll</h1>
#
# <h2 style='color:#0000b7' >&nbsp; 2.1 &nbsp;O modelo de Malthus</h2>
#
# &nbsp; &nbsp; &nbsp; O modelo populacional de Malthus é dado por:
# ​
# $$\frac{dP}{dt}=κP$$
# ​
# &nbsp; &nbsp; onde <b>P</b> é o número de habitantes e <b>κ</b> a constante de proporcionalidade.
#
# <h3 style='color:#b50000' >&nbsp; &nbsp; 2.1.1 &nbsp;Solução da equação diferencial</h3>
#
# &nbsp; &nbsp; &nbsp; &nbsp; Inicialmente, obtemos a solução da equação diferencial por separação de variáveis:
#
# $$\frac{dP}{dt}=κP \Rightarrow \frac{dP}{κP}=dt $$
#
# &nbsp; &nbsp; &nbsp; &nbsp; Integrando a equação:
#
# $$ \int\frac{dP}{P} = \int κdt \Rightarrow ln|P|+C_{1} = κt + C_{2} \Rightarrow ln|P| = κt + C $$
#
# &nbsp; &nbsp; &nbsp; &nbsp;  Isolando <b>P</b>,temos:
#
# $$ P = e^{κt + C}$$
#
# &nbsp; &nbsp; &nbsp; &nbsp;  Tomando $e^{C}$ como a população inicial $P_{0}$ temos a solução analítica do problema de contorno:
#
# $$ P(t) = P_{0}\:e^{κt}$$
#
# <h3 style='color:#b50000' >&nbsp; &nbsp; 2.1.2 &nbsp;Solução do problema de contorno</h3>
#
# &nbsp; &nbsp; &nbsp; &nbsp;  Em $t=0$ a população era de 197 228 habitantes, logo:
#
# $$ P(0)=P_{0}e^{κ(0)} \Rightarrow 197 \: 228 = P_{0} $$
#
# &nbsp; &nbsp; &nbsp; &nbsp;  Dessa forma, $P(t)$:
#
# $$ P(t) = 197228\:e^{κt}$$
#
# &nbsp; &nbsp; &nbsp; &nbsp;  Mas, em $t=2$ a população era de 198 842, então:
#
# $$ P(10) = 197228\:e^{(2)κ} \Rightarrow 198 842 = 197228\:e^{2κ} \Rightarrow \frac{198 842}{197228}=e^{2κ} \Rightarrow $$ <br>
#
# $$ \Rightarrow ln \left ( \frac{198 842}{197228}\right ) = 2κ \Rightarrow κ=\frac{1}{2}ln \left ( \frac{198 842}{197228} \right ) \approx 0.00407$$
#
# &nbsp; &nbsp; &nbsp; &nbsp;  Portanto, segundo o modelo de Malthus, a equação que descreve o número de habitantes de Rio Grande - RS sob as condições do <br>  &nbsp; &nbsp; &nbsp; enunciado é dada por:
#
# $$ P(t)=197228e^{0.00407t}$$

# %% [markdown]
# <h2 style='color:#0000b7' >&nbsp; 2.2 &nbsp;O modelo de Verhulst</h2>
#
#
# &nbsp; &nbsp; &nbsp; <b style='color:#b50000'>Referência:</b> <b>A Short History of Mathematical Population Dynamics</b>, Nicolas Bacaër.
#
# &nbsp; &nbsp; &nbsp; O modelo populacional de Verhulst é dado por:
#
# $$\frac{dP}{dt}=  κP\left ( 1- \frac{P}{L} \ \right ) $$
#
# &nbsp; &nbsp; &nbsp; Onde <b>P</b> é o número de habitantes, <b>L</b> é um limite estipulado em decorrência da competitividade, e, <b>κ</b> a constante de crescimento de uma <br> &nbsp; &nbsp; população em determinada época.
#
# <h3 style='color:#b50000' >&nbsp; &nbsp; 2.2.1 &nbsp;Solução da equação diferencial</h3>
#
# &nbsp; &nbsp; &nbsp; &nbsp;  A solução analítica do modelo de Verhulst é dada por:
#
# $$P(t)=\frac{L P_{0}e^{κt}}{L+P_{0}(e^{κt}-1)}$$
#
# <h3 style='color:#b50000' >&nbsp; &nbsp; 2.2.2 &nbsp;Estivamativa dos parâmetros κ e L</h3>
# &nbsp; &nbsp; &nbsp; &nbsp;   Se $P_{0}$ é a população no instante $t=0$, $P_{1}$ no instante $t=T$ e $P_{2}$ no instante $t=2T$ podemos estimar os parâmetros κ e L da seguinte <br> &nbsp; &nbsp;  forma:
#
# $$ L = P_{1}\frac{P_{0}P_{1}+P_{1}P_{2}-2P_{0}P_{2}}{P_{1}^{2}-P_{0}P_{2}}, \: κ = \frac{1}{T}ln\left ( \frac{1/P_{0}-1/L}{1/P_{1}-1/L} \right ) $$
#
# &nbsp; &nbsp; &nbsp; &nbsp; Sabendo que $P_{0}=197\:228$, $P_{1}=198\: 049$, $P_{2}=198\:842$ e $T=1$, os parâmetros para o problema proposto são:
#
# $$ L = 198049\frac{197228*198049+198049*198842-2*197228*198842}{198049^{2}-197228*198842} \approx 218 \: 858$$
# <br>
# $$ κ = ln\left ( \frac{1/197228-1/218858}{1/198049-1/218858} \right ) \approx 0.04285 $$

# %% [markdown]
# <h3 style='color:#b50000' >&nbsp; &nbsp; 2.2.3 &nbsp;Solução geral do problema</h3>
#
# &nbsp; &nbsp; &nbsp; &nbsp; Substituindo $κ$, $L$ e $P_{0}$ na solução geral do problema, temos:
#
# $$P(t)=\frac{218858(197228)e^{0.04285t}}{218858+197228(e^{0.04285t}-1)}$$

# %% [markdown]
# <h2 style='color:#0000b7' >&nbsp; 2.3 &nbsp;O Modelo de Montroll</h2>
#
# &nbsp; &nbsp; &nbsp; <b style='color:#b50000'>Referência:</b> <b>Estudo da evolução de modelos de
# crescimento populacional e métodos para obtenção de parâmetros</b>, Alex Alves <br>  &nbsp; &nbsp; &nbsp; Dentamaro.
# <br><br>
# &nbsp; &nbsp; &nbsp; A equação de dinâmica populacional formulada por Montroll é apresentada da seguinte forma:
#
# $$\frac{dP}{dt}= κP \left [  1- \left ( \frac{P}{L} \ \right )^{\lambda} \right ]$$
#
# &nbsp; &nbsp; &nbsp; Onde <b>P</b> é o número de habitantes, <b>L</b> é um limite estipulado em decorrência da competitividade, <b>κ</b> é a constante de crescimento de uma <br> &nbsp; &nbsp; população em determinada época e $\lambda$ indica a posição do ponto de inflexão da curva. Em particular, se $\lambda=1$ temos o modelo de Verhulst.
#
# <h3 style='color:#b50000' >&nbsp; &nbsp; 2.3.1 &nbsp;Solução da equação diferencial</h3>
#
# &nbsp; &nbsp; &nbsp; &nbsp;  A solução analítica do modelo de Montroll é dada por:
#
# $$P(t)=\frac{L}{ (1 + ce^{-\lambda κ t})^{1/\lambda}}$$
#
# &nbsp; &nbsp; &nbsp; onde,
#
# $$ κ = \frac{\alpha}{\lambda}, \: c = e^{-\beta}$$
#
# &nbsp; &nbsp; &nbsp; &nbsp; As constantes $\alpha$ e $\beta$ são relacionadas à função ajuste linear, veja a subseção <b>2.3.4</b>.

# %% [markdown]
# <h3 style='color:#b50000' >&nbsp; &nbsp; 2.3.2 &nbsp;Estivamativa do parâmetro L obtido através de outro modelo</h3>

# %% [markdown]
# <h3 style='color:#b50000' >&nbsp; &nbsp; 2.3.3 &nbsp;Estivamativa do parâmetro $\lambda$ </h3>
#
#
#
# &nbsp; &nbsp; &nbsp; &nbsp; Seja $P$ um ajuste polinominal de grau $n>1$ dos dados da Tabela 1 e $t_{m}$ o ponto de inflexão oblíquo de $P$, então é verdade que:
#
# $$ P(t_{m}) = \frac{L}{(1+\lambda)^{1/\lambda}} .$$
#
# &nbsp; &nbsp; &nbsp; &nbsp;  Realizando uma regressão quadrática para os dados da Tabela 1 chegamos à seguinte equação:
#
# $$ P(t) = −334.9333t^3+990.8t^2+165.1333t+197228 $$
#
# &nbsp; &nbsp; &nbsp; &nbsp; Para que $t_{m}$ seja um ponto de inflexão oblíquo, devem ser satisfeitas as condições:
#
# $$ P(t)\vert_{t_{m}} \neq 0, \: P''(t)\vert_{t_{m}} = 0 \: , P'''(t)\vert_{t_{m}} \neq 0 .$$
#
# &nbsp; &nbsp; &nbsp; &nbsp; Assim:
#
# $$ P''(t_{m}) = 1981.6-2009.5998\cdot t_{m} = 0 \Rightarrow t_{m} =0.986,$$,
# $$ P(t_{m}) \neq 0 ,$$,
# $$ P'''(t_{m}) \neq 0 .$$
#
# &nbsp; &nbsp; &nbsp; &nbsp; com,
#
# $$ P_{m}(t_{m})=198033.011$$
#
# &nbsp; &nbsp; &nbsp; &nbsp;  Finalmente, determinando $\lambda$:
#
# $$ 209678.4464=\frac{218858}{(1+\lambda)^{1/\lambda}}\Rightarrow \lambda \cong 107.83037  .$$

# %% [markdown]
# <h3 style='color:#b50000' >&nbsp; &nbsp; 2.3.4 &nbsp;Função ajuste linear para o modelo de Montroll</h3>
#
# &nbsp; &nbsp; &nbsp; &nbsp;  A função ajuste linear para o modelo de Montroll é determinado da seguinte forma:
#
# $$z=ln\left [ \frac{\left ( \frac{P}{L} \right )^{\lambda}}{1-\left ( \frac{P}{L} \right )^{\lambda}} \right ]=\alpha t + \beta$$
#
# &nbsp; &nbsp; &nbsp; &nbsp; Os coeficientes $\alpha$ e $\beta$ da equação anterior são ajustados por meio das equações:
#
#
# $$\alpha = \frac{\sum_{i=1}^{n}t_{i}z_{i}-\left ( \sum_{i=1}^{n}t_{i} \right )\left ( \sum_{i=1}^{n}z_{i} \right )}{n\sum_{i=1}^{n}t_{i}^{2}-\left ( \sum_{i=1}^{n}t_{i} \right )^2}$$
#
# $$ \beta = \frac{1}{n}\left ( \sum_{i=1}^{n}z_{i} - \alpha \sum_{i=1}^{n}t_{i} \right ) $$
#
# &nbsp; &nbsp; &nbsp; &nbsp; Para calcular tais quantidades pode-se construir uma tabela contendo os parâmetros necessários para o ajuste:
#
# <center><b>Tabela 1 - Parâmetros do ajuste linear</b></center>
#
# |i| Ano |ti| Pi | zi | ti^2 | ti$\cdot$zi |
# | --- | --- | --- | --- | --- | --- | --- |
# |1| 2010 | 0 |197 228 | -11.22 | 0 |0 |
# |2| 2011 | 1 |198 049 | -10.77 | 1|-10.77 |
# |3| 2012 | 2 |198 842 | -10.34| 4|-20.68 |
# |Σ| | 3|| -32.33| 5|-31.45 |
# <center>Fonte: O autor</center>
#
# &nbsp; &nbsp; &nbsp; Substituindo os somatórios nas equações de ajuste linear, obtém-se:
#
# $$\alpha=\frac{3(-31.45)-3(-32.33)}{3(5)-(3)^2} = 0.44 $$
# $$ \beta=\frac{1}{3}\left [ -32.33-0.44(3) \right ] \approx -11.22$$
#
# &nbsp; &nbsp; &nbsp; Utilizando as relações entre $\alpha$, $\beta$, $\lambda$, $κ$ e $c$ para determinar $r$ e $c$:
#
# $$ κ = \frac{0.44}{107.83} \approx 0.004$$
# $$ c = e^{-(-11.22)} \approx 74607.77$$

# %% [markdown]
# <h3 style='color:#b50000' >&nbsp; &nbsp; 2.3.5 &nbsp;Solução geral do problema</h3>
# &nbsp; &nbsp; &nbsp; Finalmente, substituindo os parâmetros $\lambda$, $κ$ e $c$ na solução do modelo de Montroll:
#
# $$P(t)=\frac{218\:858}{ (1 + 74607.77e^{-\lambda 0.004 t})^{1/107.83}}$$
